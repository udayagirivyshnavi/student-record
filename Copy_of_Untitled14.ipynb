# %% [markdown]
# <a href="https://colab.research.google.com/github/udayagirivyshnavi/student-record/blob/main/Copy_of_Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = []

while True:
    print("\nStudent Management System")
    print("1. Add Student")
    print("2. View Students")
    print("3. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        name = input("Enter student name: ")
        students.append(name)
        print("Student added successfully!")

    elif choice == "2":
        print("\nStudent List:")
        for student in students:
            print(student)

    elif choice == "3":
        print("Exiting...")
        break

    else:
        print("Invalid choice!")
# Out:
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Exit
# Enter your choice: 2
#
# Student List:
#
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Exit
# Enter your choice: 1
# Enter student name: vyshu
# Student added successfully!
#
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Exit
# Enter your choice: 2
#
# Student List:
# vyshu
#
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Exit
# Enter your choice: 3
# Exiting...
